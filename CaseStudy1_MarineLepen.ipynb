# %% [markdown]
# ## Twitter scraping with [minet](https://github.com/medialab/minet)
# `Notebook created by A.Pournaki for DDPS (SciencesPo/CEU 2022)`
#
# Since the standard Twitter API only allows to retrieve of tweets from the past week, we may recur to scraping in order to collect tweets that were published earlier than this. The downside of this method is that it is a bit slower and that it does not allow us to retrieve any retweet information.
#
# With the powerful tool [minet](https://github.com/medialab/minet), we can scrape tweets from the public API using an [advanced search query](https://help.twitter.com/en/using-twitter/twitter-advanced-search).

# %%
# !pip install minet
# Out:
# Requirement already satisfied: minet in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (0.58.1)
# Requirement already satisfied: casanova<0.18,>=0.17.1 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from minet) (0.17.1)
# Requirement already satisfied: soupsieve>=2.1 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from minet) (2.2.1)
# Requirement already satisfied: tqdm>=4.60.0 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from minet) (4.62.3)
# Requirement already satisfied: tenacity>=7.0.0 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from minet) (8.0.1)
# Requirement already satisfied: lxml>=4.3.0 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from minet) (4.8.0)
# Requirement already satisfied: keyring<19.3 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from minet) (19.2.0)
# Requirement already satisfied: persist-queue>=0.7.0 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from minet) (0.7.0)
# Requirement already satisfied: urllib3[secure]<2,>=1.25.3 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from minet) (1.26.7)
# Requirement already satisfied: twitwi<0.11,>=0.10.0 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from minet) (0.10.1)
# Requirement already satisfied: json5>=0.8.5 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from minet) (0.9.6)
# Requirement already satisfied: ebbe<2,>=1.3.1 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from minet) (1.6.0)
# Requirement already satisfied: termcolor>=1.0.0 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from minet) (1.1.0)
# Requirement already satisfied: trafilatura<0.10,>=0.9.1 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from minet) (0.9.3)
# Requirement already satisfied: beautifulsoup4>=4.7.1 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from minet) (4.10.0)
# Requirement already satisfied: dateparser>=1.0.0 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from minet) (1.1.0)
# Requirement already satisfied: browser-cookie3==0.13.0 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from minet) (0.13.0)
# Requirement already satisfied: cchardet>=2.1.7 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from minet) (2.1.7)
# Requirement already satisfied: quenouille<2,>=1.4.2 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from minet) (1.4.2)
# Requirement already satisfied: ural<0.33,>=0.32.0 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from minet) (0.32.1)
# Requirement already satisfied: ndjson>=0.3.1 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from minet) (0.3.1)
# Requirement already satisfied: pyyaml in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from minet) (6.0)
# Requirement already satisfied: colorama>=0.4.0 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from minet) (0.4.4)
# Requirement already satisfied: pyaes in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from browser-cookie3==0.13.0->minet) (1.6.1)
# Requirement already satisfied: pycryptodome in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from browser-cookie3==0.13.0->minet) (3.14.1)
# Requirement already satisfied: pbkdf2 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from browser-cookie3==0.13.0->minet) (1.3)
# Requirement already satisfied: lz4 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from browser-cookie3==0.13.0->minet) (4.0.0)
# Requirement already satisfied: SecretStorage in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from browser-cookie3==0.13.0->minet) (3.3.1)
# Requirement already satisfied: file-read-backwards<3,>=2.0.0 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from casanova<0.18,>=0.17.1->minet) (2.0.0)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from dateparser>=1.0.0->minet) (2021.8.3)
# Requirement already satisfied: pytz in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from dateparser>=1.0.0->minet) (2021.3)
# Requirement already satisfied: python-dateutil in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from dateparser>=1.0.0->minet) (2.8.2)
# Requirement already satisfied: tzlocal in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from dateparser>=1.0.0->minet) (4.1)
# Requirement already satisfied: entrypoints in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from keyring<19.3->minet) (0.3)
# Requirement already satisfied: courlan>=0.4.2 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from trafilatura<0.10,>=0.9.1->minet) (0.6.0)
# Requirement already satisfied: charset-normalizer>=2.0.7 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from trafilatura<0.10,>=0.9.1->minet) (2.0.12)
# Requirement already satisfied: certifi in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from trafilatura<0.10,>=0.9.1->minet) (2021.10.8)
# Requirement already satisfied: justext>=3.0.0 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from trafilatura<0.10,>=0.9.1->minet) (3.0.0)
# Requirement already satisfied: htmldate>=0.9.1 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from trafilatura<0.10,>=0.9.1->minet) (1.1.1)
# Requirement already satisfied: readability-lxml>=0.8.1 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from trafilatura<0.10,>=0.9.1->minet) (0.8.1)
# Requirement already satisfied: twitter==2.0a0 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from twitwi<0.11,>=0.10.0->minet) (2.0a0)
# Requirement already satisfied: tld<1,>=0.12.1 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from ural<0.33,>=0.32.0->minet) (0.12.6)
# Requirement already satisfied: phylactery<0.3,>=0.2.3 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from ural<0.33,>=0.32.0->minet) (0.2.3)
# Requirement already satisfied: pycountry<19,>=18.12.8 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from ural<0.33,>=0.32.0->minet) (18.12.8)
# Requirement already satisfied: pyOpenSSL>=0.14 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from urllib3[secure]<2,>=1.25.3->minet) (21.0.0)
# Requirement already satisfied: cryptography>=1.3.4 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from urllib3[secure]<2,>=1.25.3->minet) (3.4.8)
# Requirement already satisfied: idna>=2.0.0 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from urllib3[secure]<2,>=1.25.3->minet) (3.2)
# Requirement already satisfied: langcodes>=3.2.1 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from courlan>=0.4.2->trafilatura<0.10,>=0.9.1->minet) (3.3.0)
# Requirement already satisfied: cffi>=1.12 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from cryptography>=1.3.4->urllib3[secure]<2,>=1.25.3->minet) (1.14.6)
# Requirement already satisfied: six>=1.5.2 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from pyOpenSSL>=0.14->urllib3[secure]<2,>=1.25.3->minet) (1.16.0)
# Requirement already satisfied: cssselect in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from readability-lxml>=0.8.1->trafilatura<0.10,>=0.9.1->minet) (1.1.0)
# Requirement already satisfied: chardet in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from readability-lxml>=0.8.1->trafilatura<0.10,>=0.9.1->minet) (4.0.0)
# Requirement already satisfied: jeepney>=0.6 in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from SecretStorage->browser-cookie3==0.13.0->minet) (0.7.1)
# Requirement already satisfied: pytz-deprecation-shim in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from tzlocal->dateparser>=1.0.0->minet) (0.1.0.post0)
# Requirement already satisfied: pycparser in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=1.3.4->urllib3[secure]<2,>=1.25.3->minet) (2.20)
# Requirement already satisfied: tzdata in /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages (from pytz-deprecation-shim->tzlocal->dateparser>=1.0.0->minet) (2021.5)

# %% [markdown]
# Minet is best used as a command-line-utility, so we just run the command we would usually run in our terminal here:

# %%
# !minet tw scrape --help
# Out:
# usage: minet twitter scrape [-h] [--rcfile RCFILE] [--include-refs] [-l LIMIT]
#                             [-o OUTPUT] [--query-template QUERY_TEMPLATE]
#                             [-s SELECT]
#                             {tweets,users} query [file]
#
# Minet Twitter Scrape Command
# ============================
#
# Scrape Twitter's public facing search API to collect tweets or users.
#
# Be sure to check Twitter's advanced search to check what kind of
# operators you can use to tune your queries (time range, hashtags,
# mentions, boolean etc.):
# https://twitter.com/search-advanced?f=live
#
# Useful operators include "since" and "until" to search specific
# time ranges like so: "since:2014-01-01 until:2017-12-31".
#
# positional arguments:
#   {tweets,users}                   What to scrape. Currently only `tweets` and `users` are possible.
#   query                            Search query or name of the column containing queries to run in given CSV file.
#   file                             Optional CSV file containing the queries to be run.
#
# optional arguments:
#   -h, --help                       show this help message and exit
#   --rcfile RCFILE                  Custom path to a minet configuration file.
#   --include-refs                   Whether to emit referenced tweets (quoted, retweeted & replied) in the CSV output. Note that it consumes a memory proportional to the total number of unique tweets retrieved.
#   -l LIMIT, --limit LIMIT          Maximum number of tweets or users to collect per query.
#   -o OUTPUT, --output OUTPUT       Path to the output file. By default, the results will be printed to stdout.
#   --query-template QUERY_TEMPLATE  Query template. Can be useful for instance to change a column of twitter user screen names into from:@user queries.
#   -s SELECT, --select SELECT       Columns of input CSV file to include in the output (separated by `,`).
#
# examples:
#
# . Collecting the latest 500 tweets of a given Twitter user:
#     $ minet tw scrape tweets "from:@jack" --limit 500 > tweets.csv
#
# . Collecting the tweets from multiple Twitter queries listed in a CSV file:
#     $ minet tw scrape tweets query queries.csv > tweets.csv
#
# . Templating the given CSV column to query tweets by users:
#     $ minet tw scrape tweets user users.csv --query-template 'from:@{value}' > tweets.csv
#
# . Tip: You can add a "OR @aNotExistingHandle" to your query to avoid searching
#   for your query terms in usernames or handles.
#   Note that this is a temporary hack which might stop working at any time so be
#   sure to double check before relying on this trick.
#   For more information see the related discussion here:
#   https://webapps.stackexchange.com/questions/127425/how-to-exclude-usernames-and-handles-while-searching-twitter
#
#     $ minet tw scrape tweets "keyword OR @anObviouslyNotExistingHandle"
#
# . Collecting users with "adam" in their user_name or user_description:
#     $ minet tw scrape users adam > users.csv

# %% [markdown]
# Let's try to scrape some tweets using an [advanced search query](https://help.twitter.com/en/using-twitter/twitter-advanced-search).

# %%
# !minet tw scrape tweets "(from:@MLP_officiel) étrangers OR clandestins OR migrants OR immigrés OR réfugiés OR immigration OR migration OR remigration OR migratoire OR accueil" --limit 400 > tweets.csv
# Out:
# Searching for "(from:@MLP_officiel) étrangers OR clandestins OR migrants OR immigrés OR réfugiés OR immigration OR migration OR remigration OR migratoire OR accueil"
# Collecting tweet: 100%|█| 400/400 [00:15<00:00, 25.07tweet/s, queries=1, tokens=

# %% [markdown]
# We can now load and inspect this dataframe with pandas

# %%
import pandas as pd

# %%
df0 = pd.read_csv("./tweets.csv")

# %%
print(df0.columns)
# Out:
# Index(['query', 'id', 'timestamp_utc', 'local_time', 'user_screen_name',
#        'text', 'possibly_sensitive', 'retweet_count', 'like_count',
#        'reply_count', 'lang', 'to_username', 'to_userid', 'to_tweetid',
#        'source_name', 'source_url', 'user_location', 'lat', 'lng', 'user_id',
#        'user_name', 'user_verified', 'user_description', 'user_url',
#        'user_image', 'user_tweets', 'user_followers', 'user_friends',
#        'user_likes', 'user_lists', 'user_created_at', 'user_timestamp_utc',
#        'collected_via', 'match_query', 'retweeted_id', 'retweeted_user',
#        'retweeted_user_id', 'retweeted_timestamp_utc', 'quoted_id',
#        'quoted_user', 'quoted_user_id', 'quoted_timestamp_utc',
#        'collection_time', 'url', 'place_country_code', 'place_name',
#        'place_type', 'place_coordinates', 'links', 'domains', 'media_urls',
#        'media_files', 'media_types', 'mentioned_names', 'mentioned_ids',
#        'hashtags', 'intervention_type', 'intervention_text',
#        'intervention_url'],
#       dtype='object')

# %%
print(df0['text'])
# Out:
# 0      📹 Avec mon projet présidentiel, je vous rendra...
# 1      Je renforcerai le contrôle aux frontières de n...
# 2      📹 Je veux rendre aux Français leur argent, ave...
# 3      📹 Je veux une mesure pérenne, qui est la baiss...
# 4      Merci pour votre accueil, ici, à Pointe-à-Pitr...
#                              ...
# 395    "L'UE actuelle est carcérale : son bilan est t...
# 396    "En pointe pour ouvrir nos frontières à l'immi...
# 397    « La France doit être digne de son histoire, d...
# 398    "Vous le savez ici parce que vous le constatez...
# 399    🇨🇵 🇪🇪 Merci à nos amis estoniens du mouvement ...
# Name: text, Length: 400, dtype: object

# %%
#DATA CLEANING

# %%
#imports
import nltk #import the natural language toolkit library
from nltk.stem.snowball import FrenchStemmer #import the French stemming library
from nltk.corpus import stopwords #import stopwords from nltk corpus
import re #import the regular expressions library; will be used to strip punctuation

# %%
#Remove URLS
def url_free_text(text):
    '''cleans text from urls'''
    text = re.sub(r'http\S+', '', text)
    return text

df0['url_free_tweets'] = df0['text'].apply(url_free_text)
print(df0['url_free_tweets'])
# Out:
# 0      📹 Avec mon projet présidentiel, je vous rendra...
# 1      Je renforcerai le contrôle aux frontières de n...
# 2      📹 Je veux rendre aux Français leur argent, ave...
# 3      📹 Je veux une mesure pérenne, qui est la baiss...
# 4      Merci pour votre accueil, ici, à Pointe-à-Pitr...
#                              ...
# 395    "L'UE actuelle est carcérale : son bilan est t...
# 396    "En pointe pour ouvrir nos frontières à l'immi...
# 397    « La France doit être digne de son histoire, d...
# 398    "Vous le savez ici parce que vous le constatez...
# 399    🇨🇵 🇪🇪 Merci à nos amis estoniens du mouvement ...
# Name: url_free_tweets, Length: 400, dtype: object

# %%
#Remove punctuation
def keep_only_words(text):
    '''filtering out the punctuation'''
    cleaned_text = re.sub(r'([^\w\s]|_)',' ',text)
    cleaned_text = re.sub(r'\s+', ' ', cleaned_text, flags=re.U).strip()
    #no_punctuation = re.sub(r'([^\w\s]|_)','',tokens)
    #tokens = nltk.word_tokenize(no_punctuation) #generate a list of tokens from the raw text
    #text=nltk.Text(tokens,encoding)
    return cleaned_text

df0['nopunctuation'] = df0['url_free_tweets'].apply(keep_only_words)
print(df0['nopunctuation'])
# Out:
# 0      Avec mon projet présidentiel je vous rendrai v...
# 1      Je renforcerai le contrôle aux frontières de n...
# 2      Je veux rendre aux Français leur argent avec d...
# 3      Je veux une mesure pérenne qui est la baisse d...
# 4      Merci pour votre accueil ici à Pointe à Pitre ...
#                              ...
# 395    L UE actuelle est carcérale son bilan est terr...
# 396    En pointe pour ouvrir nos frontières à l immig...
# 397    La France doit être digne de son histoire de s...
# 398    Vous le savez ici parce que vous le constatez ...
# 399    Merci à nos amis estoniens du mouvement EKRE a...
# Name: nopunctuation, Length: 400, dtype: object

# %%
#Create a Stopwords list
stopword_list = stopwords.words('french') #create a list of all French stopwords
print(stopword_list)
# Out:
# ['au', 'aux', 'avec', 'ce', 'ces', 'dans', 'de', 'des', 'du', 'elle', 'en', 'et', 'eux', 'il', 'ils', 'je', 'la', 'le', 'les', 'leur', 'lui', 'ma', 'mais', 'me', 'même', 'mes', 'moi', 'mon', 'ne', 'nos', 'notre', 'nous', 'on', 'ou', 'par', 'pas', 'pour', 'qu', 'que', 'qui', 'sa', 'se', 'ses', 'son', 'sur', 'ta', 'te', 'tes', 'toi', 'ton', 'tu', 'un', 'une', 'vos', 'votre', 'vous', 'c', 'd', 'j', 'l', 'à', 'm', 'n', 's', 't', 'y', 'été', 'étée', 'étées', 'étés', 'étant', 'étante', 'étants', 'étantes', 'suis', 'es', 'est', 'sommes', 'êtes', 'sont', 'serai', 'seras', 'sera', 'serons', 'serez', 'seront', 'serais', 'serait', 'serions', 'seriez', 'seraient', 'étais', 'était', 'étions', 'étiez', 'étaient', 'fus', 'fut', 'fûmes', 'fûtes', 'furent', 'sois', 'soit', 'soyons', 'soyez', 'soient', 'fusse', 'fusses', 'fût', 'fussions', 'fussiez', 'fussent', 'ayant', 'ayante', 'ayantes', 'ayants', 'eu', 'eue', 'eues', 'eus', 'ai', 'as', 'avons', 'avez', 'ont', 'aurai', 'auras', 'aura', 'aurons', 'aurez', 'auront', 'aurais', 'aurait', 'aurions', 'auriez', 'auraient', 'avais', 'avait', 'avions', 'aviez', 'avaient', 'eut', 'eûmes', 'eûtes', 'eurent', 'aie', 'aies', 'ait', 'ayons', 'ayez', 'aient', 'eusse', 'eusses', 'eût', 'eussions', 'eussiez', 'eussent']

# %%
#Remove Stopwords
def filter_stopwords(tweet):
    filtered_words = [] #declare an empty list to hold our filtered words
    words_in_tweet = tweet.lower().split(' ')
    
    for word in tweet.lower().split(' '): #iterate over all words from the text
        if word not in stopword_list and word.isalpha() and len(word) > 1: #only add words that are not in the French stopwords list, are alphabetic, and are more than 1 character
            filtered_words.append(word) #add word to filter_words list if it meets the above conditions
    return ' '.join(filtered_words)

df0['nostopwords'] = df0['nopunctuation'].apply(filter_stopwords)
print(df0['nostopwords'])
# Out:
# 0      projet présidentiel rendrai pays mettant fin i...
# 1      renforcerai contrôle frontières territoires ul...
# 2      veux rendre français argent grandes mesures po...
# 3      veux mesure pérenne baisse tva pèse ensemble é...
# 4              merci accueil ici pointe pitre guadeloupe
#                              ...
# 395    ue actuelle carcérale bilan terrifiant matière...
# 396    pointe ouvrir frontières immigration massive d...
# 397    france doit être digne histoire destin grandeu...
# 398    savez ici parce constatez mulhouse bien endroi...
# 399    merci amis estoniens mouvement ekre actuelleme...
# Name: nostopwords, Length: 400, dtype: object

# %%
EZtweets = df0['nostopwords']
print(EZtweets)
# Out:
# 0      projet présidentiel rendrai pays mettant fin i...
# 1      renforcerai contrôle frontières territoires ul...
# 2      veux rendre français argent grandes mesures po...
# 3      veux mesure pérenne baisse tva pèse ensemble é...
# 4              merci accueil ici pointe pitre guadeloupe
#                              ...
# 395    ue actuelle carcérale bilan terrifiant matière...
# 396    pointe ouvrir frontières immigration massive d...
# 397    france doit être digne histoire destin grandeu...
# 398    savez ici parce constatez mulhouse bien endroi...
# 399    merci amis estoniens mouvement ekre actuelleme...
# Name: nostopwords, Length: 400, dtype: object

# %%
#Word Visualisation

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
all_tweets_words = ' '.join([word for word in EZtweets.tolist()])

# %%
wordcloud = WordCloud(background_color = 'white', stopwords = stopword_list, max_words = 50).generate(all_tweets_words)
plt.imshow(wordcloud)
plt.axis("off")
plt.show();

# %%
#Topic Modelling

# %%
import textacy
import pandas as pd
from functools import partial

# %%
## compute the document-term-matrix
corpus = textacy.Corpus("en_core_web_sm",EZtweets)
docs_terms = (textacy.extract.terms(doc,ngs=partial(textacy.extract.ngrams, n=1, include_pos={"NOUN", "ADJ"}),ents=partial(textacy.extract.entities, include_types={ "ORG", "GPE", "LOC"}))for doc in corpus)
tokenized_docs = (textacy.extract.terms_to_strings(doc_terms, by="lemma") for doc_terms in docs_terms)
doc_term_matrix, vocab = textacy.representations.build_doc_term_matrix(tokenized_docs,tf_type="linear", idf_type="smooth")
id_to_term = {id_: term for term, id_ in vocab.items()}

# %%
## train the topic model using non-negative matrix factorization
import textacy.tm
model = textacy.tm.TopicModel("nmf", n_topics=6)
model.fit(doc_term_matrix)
doc_topic_matrix = model.transform(doc_term_matrix)
# Out:
# /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages/sklearn/decomposition/_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# /Users/clairemabille/opt/anaconda3/lib/python3.9/site-packages/sklearn/decomposition/_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"

# %%
## look at the top terms for every topic
for topic_idx, terms in model.top_topic_terms(id_to_term, top_n=10):
    print(f"topic {topic_idx}: {'   '.join(terms)}")
# Out:
# topic 0: immigration   insécurité   politique   massive   problème   arrêt   droit   argent   mlafrance   mayotte
# topic 1: étranger   délinquant   expulsion   peine   délinquance   double   temp   équivalent   fait   présidente
# topic 2: migrant   assistance   européenne   hébergement   humanitaire   droit   aide   face   rêver   budget
# topic 3: france   barkhane   opération   être   gestion   jour   lor   permet   participation   déploron
# topic 4: san   contre   lutter   nationale   fraude   islam   zoneinterdite   drogue   assimilation   immigration
# topic 5: tous   père   tchétchène   anzorov   vital   fait apologie   soutiennent   mariannelemag   blogueur   interview

# %%
## visualize this information
_ = model.termite_plot(doc_term_matrix, id_to_term, n_terms=50, highlight_topics=[1,2,3,4,5])
